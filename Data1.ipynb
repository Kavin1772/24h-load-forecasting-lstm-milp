# %%
import pandas as pd
import numpy as np

# Create 10 days of hourly data
date_rng = pd.date_range(start="2025-01-01", end="2025-01-10 23:00", freq="H")

# Make synthetic power consumption with daily cycles + some noise
np.random.seed(42)
power_values = 500 + 200 * np.sin(2 * np.pi * date_rng.hour / 24) + np.random.normal(0, 30, len(date_rng))

# Combine into DataFrame
df_sample = pd.DataFrame({
    "timestamp": date_rng,
    "power": power_values
})

# Save to CSV
sample_path = "sample_power_data.csv"
df_sample.to_csv(sample_path, index=False)

print(f"✅ Sample dataset saved as {sample_path}")
df_sample.head()
# Out:
# ✅ Sample dataset saved as sample_power_data.csv
# C:\Users\Kavin\AppData\Local\Temp\ipykernel_3220\62063164.py:5: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   date_rng = pd.date_range(start="2025-01-01", end="2025-01-10 23:00", freq="H")
#             timestamp       power
# 0 2025-01-01 00:00:00  514.901425
# 1 2025-01-01 01:00:00  547.615880
# 2 2025-01-01 02:00:00  619.430656
# 3 2025-01-01 03:00:00  687.112252
# 4 2025-01-01 04:00:00  666.180480

# %%
metrics = run_pipeline(
    data_path="sample_power_data.csv",
    ts_col="timestamp",
    y_col="power",
    resample="H",
    add_calendar=True,
    use_rf=True,
    outdir="outputs/test_run"
)

print(json.dumps(metrics, indent=2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 metrics = run_pipeline(
#       2     data_path="sample_power_data.csv",
#       3     ts_col="timestamp",
#       4     y_col="power",
#       5     resample="H",
#       6     add_calendar=True,
#       7     use_rf=True,
#       8     outdir="outputs/test_run"
#       9 )
#      11 print(json.dumps(metrics, indent=2))
#
# NameError: name 'run_pipeline' is not defined

# %%
import h5py

file_path = r"A:\AI in Engg\Project\ukdale.h5"
with h5py.File(file_path, "r") as f:
    print("Top-level keys:", list(f.keys()))
# Out:
# Top-level keys: ['building1', 'building2', 'building3', 'building4', 'building5']

# %%
with h5py.File(file_path, 'r') as f:
    print("Datasets in building1:", list(f['building1'].keys()))
# Out:
# Datasets in building1: ['elec']

# %%
import h5py

file_path = r"A:\AI in Engg\Project\ukdale.h5"

with h5py.File(file_path, "r") as f:
    print("Top-level keys:", list(f.keys()))
# Out:
# Top-level keys: ['building1', 'building2', 'building3', 'building4', 'building5']

# %%
with h5py.File(file_path, "r") as f:
    print("Datasets in building1:", list(f["building1"].keys()))
    print("Datasets in building1/elec:", list(f["building1"]["elec"].keys()))
# Out:
# Datasets in building1: ['elec']
# Datasets in building1/elec: ['meter1', 'meter10', 'meter11', 'meter12', 'meter13', 'meter14', 'meter15', 'meter16', 'meter17', 'meter18', 'meter19', 'meter2', 'meter20', 'meter21', 'meter22', 'meter23', 'meter24', 'meter25', 'meter26', 'meter27', 'meter28', 'meter29', 'meter3', 'meter30', 'meter31', 'meter32', 'meter33', 'meter34', 'meter35', 'meter36', 'meter37', 'meter38', 'meter39', 'meter4', 'meter40', 'meter41', 'meter42', 'meter43', 'meter44', 'meter45', 'meter46', 'meter47', 'meter48', 'meter49', 'meter5', 'meter50', 'meter51', 'meter52', 'meter53', 'meter54', 'meter6', 'meter7', 'meter8', 'meter9']

# %%
import h5py

file_path = r"A:\AI in Engg\Project\ukdale.h5"

mains_candidates = []
with h5py.File(file_path, "r") as f:
    elec = f["building1"]["elec"]
    for key in elec.keys():  # e.g., 'meter1', 'meter2', ...
        grp = elec[key]
        attrs = dict(grp.attrs)
        is_site = int(attrs.get("site_meter", 0)) == 1  # mains flag
        if is_site:
            mains_candidates.append(key)
        print(f"{key:>7}  attrs={attrs}")

print("\nMains-like meters (site_meter=1):", mains_candidates)
# Out:
#  meter1  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'apparent'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter10  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter11  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter12  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter13  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter14  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter15  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter16  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter17  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter18  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter19  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
#  meter2  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'apparent'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter20  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter21  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter22  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter23  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter24  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter25  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'apparent'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter26  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter27  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter28  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter29  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
#  meter3  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'apparent'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter30  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter31  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter32  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter33  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter34  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter35  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter36  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter37  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter38  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter39  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
#  meter4  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter40  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter41  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter42  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter43  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter44  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter45  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter46  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter47  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter48  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter49  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
#  meter5  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter50  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter51  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter52  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter53  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
# meter54  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\na(g3\nS'apparent'\np6\ntp7\na(S'voltage'\np8\nS''\ntp9\natp10\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
#  meter6  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
#  meter7  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
#  meter8  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'apparent'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
#  meter9  attrs={'CLASS': np.bytes_(b'GROUP'), 'TITLE': np.bytes_(b''), 'VERSION': np.bytes_(b'1.0'), 'data_columns': np.bytes_(b'(lp1\n.'), 'encoding': np.bytes_(b'N.'), 'index_cols': np.bytes_(b"(lp1\n(I0\nS'index'\np2\ntp3\na."), 'info': np.bytes_(b"(dp1\nI1\n(dp2\nS'type'\np3\nS'MultiIndex'\np4\nsS'names'\np5\n(lp6\nS'physical_quantity'\np7\nag3\nassS'index'\np8\n(dp9\nS'tz'\np10\ncpytz\n_p\np11\n(S'Europe/London'\np12\nI-60\nI0\nS'LMT'\np13\ntRp14\nss."), 'levels': np.int64(1), 'metadata': np.bytes_(b'(lp1\n.'), 'nan_rep': np.bytes_(b'nan'), 'non_index_axes': np.bytes_(b"(lp1\n(I1\n(lp2\n(S'power'\np3\nS'active'\np4\ntp5\natp6\na."), 'pandas_type': np.bytes_(b'frame_table'), 'pandas_version': np.bytes_(b'0.15.2'), 'table_type': np.bytes_(b'appendable_frame'), 'values_cols': np.bytes_(b"(lp1\nS'values_block_0'\np2\na.")}
#
# Mains-like meters (site_meter=1): []

# %%
import pandas as pd

file_path = r"A:\AI in Engg\Project\ukdale.h5"

with pd.HDFStore(file_path, mode="r") as store:
    keys = [k for k in store.keys() if k.startswith("/building1/elec/meter")]
    print("Found meter tables:", len(keys))
    print(keys[:15], " ...")
    # Peek the first one to see column structure
    sample = store[keys[0]]
    print("Sample columns:", sample.columns)
    print("Index tz info:", getattr(sample.index, "tz", None))
# Out:
# Found meter tables: 54
# ['/building1/elec/meter1', '/building1/elec/meter10', '/building1/elec/meter11', '/building1/elec/meter12', '/building1/elec/meter13', '/building1/elec/meter14', '/building1/elec/meter15', '/building1/elec/meter16', '/building1/elec/meter17', '/building1/elec/meter18', '/building1/elec/meter19', '/building1/elec/meter2', '/building1/elec/meter20', '/building1/elec/meter21', '/building1/elec/meter22']  ...
# Sample columns: MultiIndex([('power', 'apparent')],
#            names=['physical_quantity', 'type'])
# Index tz info: Europe/London

# %%
import pandas as pd

def read_meter_series(h5_path: str, meter_key: str) -> pd.Series:
    df = pd.read_hdf(h5_path, meter_key)
    # Prefer active; fallback to apparent
    if ("power","active") in df.columns:
        s = df[("power","active")]
    else:
        s = df[("power","apparent")]
    s = s.dropna().sort_index()
    return s

# %%
import warnings

h5 = r"A:\AI in Engg\Project\ukdale.h5"

mains_key, stats = None, []
with pd.HDFStore(h5, "r") as store:
    keys = [k for k in store.keys() if k.startswith("/building1/elec/meter")]
    for k in keys:
        try:
            s = read_meter_series(h5, k)
            m = s.resample("1min").mean().mean()
            stats.append((k, float(m)))
        except Exception as e:
            warnings.warn(f"Skip {k}: {e}")

stats.sort(key=lambda x: x[1], reverse=True)
print("Top candidates:", stats[:5])
mains_key = stats[0][0]
print("Chosen mains_key:", mains_key)
# Out:
# Top candidates: [('/building1/elec/meter22', 557.4097290039062), ('/building1/elec/meter41', 409.7539978027344), ('/building1/elec/meter1', 388.5457763671875), ('/building1/elec/meter54', 342.5327453613281), ('/building1/elec/meter39', 112.47698211669922)]
# Chosen mains_key: /building1/elec/meter22

# %%
s = read_meter_series(h5, mains_key)

# 1-min average, convert tz→UTC→naive for a clean CSV
s1 = s.resample("1min").mean()
s1 = s1.tz_convert("UTC").tz_localize(None)

df = s1.reset_index()
df.columns = ["timestamp", "power"]
csv_path = r"A:\AI in Engg\Project\ukdale_house1.csv"
df.to_csv(csv_path, index=False)
print("✅ Saved CSV:", csv_path)
print(df.head())
# Out:
# ✅ Saved CSV: A:\AI in Engg\Project\ukdale_house1.csv
#             timestamp        power
# 0 2013-02-14 20:57:00   337.375000
# 1 2013-02-14 20:58:00  1876.599976
# 2 2013-02-14 20:59:00  1974.800049
# 3 2013-02-14 21:00:00  1976.400024
# 4 2013-02-14 21:01:00  1949.699951

# %%
metrics = run_pipeline(
    data_path=r"A:\AI in Engg\Project\ukdale_house1.csv",
    ts_col="timestamp",
    y_col="power",
    resample="H",
    add_calendar=True,
    use_rf=True,
    outdir="outputs/ukdale_baseline",
)
import json; print(json.dumps(metrics, indent=2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 metrics = run_pipeline(
#       2     data_path=r"A:\AI in Engg\Project\ukdale_house1.csv",
#       3     ts_col="timestamp",
#       4     y_col="power",
#       5     resample="H",
#       6     add_calendar=True,
#       7     use_rf=True,
#       8     outdir="outputs/ukdale_baseline",
#       9 )
#      10 import json; print(json.dumps(metrics, indent=2))
#
# NameError: name 'run_pipeline' is not defined
